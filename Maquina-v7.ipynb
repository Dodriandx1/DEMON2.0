# %% [markdown]
# <a href="https://colab.research.google.com/github/Dodriandx1/DEMON2.0/blob/main/Maquina-v7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ☁️ Maquina-v7 — Cloud PC Linux + LXQt + Apache Guacamole en Google Colab
#
# > Escritorio remoto **GNU/Linux (LXQt)** accesible desde el **navegador** mediante **Apache Guacamole**.
# > Sin necesidad de instalar clientes RDP/VNC. Funciona en cualquier navegador web.
#
# **Arquitectura:**
# ```
# Google Colab → Linux → Xvfb → LXQt → x11vnc → guacd → Guacamole → Browser
# ```
#
# **Pasos:** ejecuta las celdas en orden: 1) Configuracion, 2) Instalar, 3) Iniciar, 4) Estado.

# %%
#@title ⚙️ Configuracion
GITHUB_USER = "jephersonRD"   #@param {type:"string"}
REPO        = "Maquina-v7"    #@param {type:"string"}

USERNAME = "user"             #@param {type:"string"}
PASSWORD = "password"         #@param {type:"string"}
RESOLUTION = "1920x1080"      #@param {type:"string"}
GUAC_PORT = 8080              #@param {type:"integer"}

print("✅ Configuracion lista.")
print(f"   Resolucion: {RESOLUTION}")
print(f"   Puerto Guacamole: {GUAC_PORT}")
print(f"   Usuario: {USERNAME}")
# Out:
# ✅ Configuracion lista.
#    Resolucion: 1920x1080
#    Puerto Guacamole: 8080
#    Usuario: user

# %%
#@title 📦 Instalar LXQt + Guacamole + Audio
import os

if not os.path.isdir('/content/Maquina-v7'):
    print("📥 Descargando repositorio...")
    # !curl -fsSL "https://codeload.github.com/{GITHUB_USER}/{REPO}/tar.gz/refs/heads/main" -o /tmp/maquina-v7.tar.gz
    # !tar xzf /tmp/maquina-v7.tar.gz -C /content
    # !mv /content/{REPO}-main /content/Maquina-v7
    # !rm -f /tmp/maquina-v7.tar.gz

# %cd /content/Maquina-v7/scripts

print("\n" + "="*50)
print("📦 [1/4] Instalando LXQt...")
print("="*50)
# !bash setup_lxqt.sh {RESOLUTION}

print("\n" + "="*50)
print("🔊 [2/4] Configurando audio...")
print("="*50)
# !bash setup_audio.sh

print("\n" + "="*50)
print("🔗 [3/4] Instalando VNC...")
print("="*50)
# !bash setup_vnc.sh

print("\n" + "="*50)
print("🌐 [4/4] Instalando Apache Guacamole (puede tardar 5-10 min)...")
print("="*50)
# !bash setup_guacamole.sh

print("\n✅ Instalacion completada")
# Out:
# 📥 Descargando repositorio...
# /content/Maquina-v7/scripts
#
# ==================================================
# 📦 [1/4] Instalando LXQt...
# ==================================================
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   🖥️  Instalando LXQt Desktop
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#    ↳ Actualizando repositorios...
# Get:1 https://cli.github.com/packages stable InRelease [4,685 B]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,578 B]
# Get:4 https://cli.github.com/packages stable/main amd64 Packages [356 B]
# Get:5 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:6 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,920 kB]
# Hit:8 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:10 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Get:11 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [3,186 kB]
# Hit:12 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:13 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:14 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,316 kB]
# Get:15 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [10.8 MB]
# Get:16 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 Packages [44.3 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:18 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [7,674 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [8,004 kB]
# Get:20 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [4,265 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [4,623 kB]
# Get:22 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,620 kB]
# Fetched 44.9 MB in 6s (7,597 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
#    ↳ Instalando LXQt + X11...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# fonts-liberation is already the newest version (1:1.07.4-11).
# libxcursor1 is already the newest version (1:1.2.0-2build4).
# libxcursor1 set to manually installed.
# libxi6 is already the newest version (2:1.8-1build1).
# libxi6 set to manually installed.
# libxinerama1 is already the newest version (2:1.1.4-3).
# libxinerama1 set to manually installed.
# libxrandr2 is already the newest version (2:1.5.2-1build1).
# libxrandr2 set to manually installed.
# xauth is already the newest version (1:1.1-1build2).
# xauth set to manually installed.
# libx11-6 is already the newest version (2:1.7.5-1ubuntu0.3).
# libx11-6 set to manually installed.
# xvfb is already the newest version (2:21.1.4-2ubuntu1.7~22.04.16).
# The following additional packages will be installed:
#   desktop-file-utils fonts-dejavu-core fonts-dejavu-extra fonts-noto-core
#   keyboard-configuration kwayland-data libdbusmenu-qt5-2 libdouble-conversion3
#   libencode-locale-perl libevdev2 libexif12 libfile-basedir-perl
#   libfile-desktopentry-perl libfile-mimeinfo-perl libfm-extra4 libfm-qt9
#   libglu1-mesa libgudev-1.0-0 libid3tag0 libimlib2 libimobiledevice6
#   libinput-bin libinput10 libipc-system-simple-perl libkf5screen-bin
#   libkf5screen7 libkf5solid5 libkf5solid5-data libkf5waylandclient5
#   libkf5windowsystem-data libkf5windowsystem5 liblocale-gettext-perl
#   liblxqt-globalkeys-ui0 liblxqt-globalkeys0 liblxqt0 libmd4c0
#   libmenu-cache-bin libmenu-cache3 libmtdev1 libmuparser2v5 libobrender32v5
#   libobt2v5 libplist3 libpolkit-qt5-1-1 libqt5core5a libqt5dbus5 libqt5gui5
#   libqt5network5 libqt5svg5 libqt5widgets5 libqt5x11extras5 libqt5xdg3
#   libqt5xdgiconloader3 libqt5xml5 libqtermwidget5-0 libstartup-notification0
#   libstatgrab10 libsysstat-qt5-0 libudev1 liburi-perl libusbmuxd6 libutf8proc2
#   libwacom-common libwacom9 libxcb-icccm4 libxcb-image0 libxcb-keysyms1
#   libxcb-render-util0 libxcb-res0 libxcb-util1 libxcb-xinerama0 libxcb-xinput0
#   libxcb-xkb1 libxcomposite1 libxcvt0 libxdo3 libxkbcommon-x11-0 libxxf86dga1
#   lxmenu-data lxqt-config lxqt-globalkeys lxqt-notificationd lxqt-policykit
#   lxqt-runner lxqt-sudo lxqt-system-theme lxqt-themes python3-apport
#   python3-problem-report python3-yaml qtermwidget5-data udev x11-apps
#   x11-session-utils xfonts-base xfonts-encodings xfonts-utils xinit xinput
#   xorg-docs-core xserver-xorg xserver-xorg-core xserver-xorg-input-all
#   xserver-xorg-input-libinput
# Suggested packages:
#   libusbmuxd-tools qt5-image-formats-plugins qtwayland5 libbusiness-isbn-perl
#   libwww-perl adwaita-qt cmst | network-manager-gnome faenza-icon-theme
#   gnome-themes-standard gparted | partitionmanager lxappearance obconf-qt
#   qt5-style-plugins synaptic feathernotes firefox | www-browser lxqt
#   lxqt-openssh-askpass preload tint2 openbox-gnome-session openbox-kde-session
#   cdtool mesa-utils nickle cairo-5c xorg-docs xfonts-100dpi xfonts-75dpi
#   x11-xfs-utils xfonts-100dpi | xfonts-75dpi xfonts-scalable
# Recommended packages:
#   fonts-noto-cjk fonts-noto-cjk-extra fonts-noto-color-emoji fonts-noto-extra
#   fonts-noto-mono fonts-noto-ui-core fonts-noto-ui-extra fonts-noto-unhinted
#   libio-stringy-perl libfm-qt-l10n usbmuxd hwdata media-player-info
#   kwayland-integration qtwayland5 liblxqt-l10n qttranslations5-l10n
#   qt5-gtk-platformtheme fonts-hack libwacom-bin galternatives lxqt-config-l10n
#   lxqt-powermanagement system-config-printer featherpad lximage-qt lxqt-about
#   lxqt-branding-debian | lxqt-branding pavucontrol-qt | pavucontrol qlipper
#   | clipit | xfce4-clipman qps lxqt-archiver | xarchiver | ark | engrampa
#   xscreensaver lxqt-globalkeys-l10n lxqt-notificationd-l10n lxqt-panel-l10n
#   qlipper lxqt-policykit-l10n lxqt-runner-l10n lxqt-session-l10n xscreensaver
#   | gnome-screensaver | light-locker | i3lock | suckless-tools lxqt-sudo-l10n
#   oxygen-icon-theme | breeze-icon-theme | faenza-icon-theme obconf | obconf-qt
#   scrot eject ffmpegthumbnailer gvfs-backends gvfs-fuse papirus-icon-theme
#   | breeze-icon-theme | faenza-icon-theme | oxygen-icon-theme pcmanfm-qt-l10n
#   apport qterminal-l10n systemd-hwe-hwdb xbitmaps xfonts-scalable
#   mesa-vulkan-drivers xserver-xorg-legacy xserver-xorg-video-all xcvt
#   xserver-xorg-input-wacom
# The following NEW packages will be installed:
#   dbus-x11 desktop-file-utils fonts-dejavu fonts-dejavu-core
#   fonts-dejavu-extra fonts-noto fonts-noto-core keyboard-configuration
#   kwayland-data libdbusmenu-qt5-2 libdouble-conversion3 libencode-locale-perl
#   libevdev2 libexif12 libfile-basedir-perl libfile-desktopentry-perl
#   libfile-mimeinfo-perl libfm-extra4 libfm-qt9 libglu1-mesa libgudev-1.0-0
#   libid3tag0 libimlib2 libimobiledevice6 libinput-bin libinput10
#   libipc-system-simple-perl libkf5screen-bin libkf5screen7 libkf5solid5
#   libkf5solid5-data libkf5waylandclient5 libkf5windowsystem-data
#   libkf5windowsystem5 liblocale-gettext-perl liblxqt-globalkeys-ui0
#   liblxqt-globalkeys0 liblxqt0 libmd4c0 libmenu-cache-bin libmenu-cache3
#   libmtdev1 libmuparser2v5 libobrender32v5 libobt2v5 libplist3
#   libpolkit-qt5-1-1 libqt5core5a libqt5dbus5 libqt5gui5 libqt5network5
#   libqt5svg5 libqt5widgets5 libqt5x11extras5 libqt5xdg3 libqt5xdgiconloader3
#   libqt5xml5 libqtermwidget5-0 libstartup-notification0 libstatgrab10
#   libsysstat-qt5-0 liburi-perl libusbmuxd6 libutf8proc2 libwacom-common
#   libwacom9 libxcb-icccm4 libxcb-image0 libxcb-keysyms1 libxcb-render-util0
#   libxcb-res0 libxcb-util1 libxcb-xinerama0 libxcb-xinput0 libxcb-xkb1
#   libxcomposite1 libxcvt0 libxdo3 libxkbcommon-x11-0 libxtst6 libxxf86dga1
#   lxmenu-data lxqt-config lxqt-core lxqt-globalkeys lxqt-notificationd
#   lxqt-panel lxqt-policykit lxqt-qtplugin lxqt-runner lxqt-session lxqt-sudo
#   lxqt-system-theme lxqt-themes openbox pcmanfm-qt python3-apport
#   python3-problem-report python3-yaml qterminal qtermwidget5-data udev
#   x11-apps x11-session-utils x11-utils x11-xserver-utils xclip xdotool
#   xfonts-base xfonts-encodings xfonts-utils xinit xinput xorg xorg-docs-core
#   xsel xserver-xorg xserver-xorg-core xserver-xorg-input-all
#   xserver-xorg-input-libinput
# The following packages will be upgraded:
#   libudev1
# 1 upgraded, 120 newly installed, 0 to remove and 116 not upgraded.
# Need to get 45.2 MB of archives.
# After this operation, 143 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 liblocale-gettext-perl amd64 1.07-4build3 [17.1 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 keyboard-configuration all 1.205ubuntu3 [206 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libdouble-conversion3 amd64 3.1.7-4 [39.0 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libqt5core5a amd64 5.15.3+dfsg-2ubuntu0.2 [2,006 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/main amd64 libevdev2 amd64 1.12.1+dfsg-1 [39.5 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/main amd64 libmtdev1 amd64 1.1.6-1build4 [14.5 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libudev1 amd64 249.11-0ubuntu3.22 [75.9 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgudev-1.0-0 amd64 1:237-2build1 [16.3 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy/main amd64 libwacom-common all 2.2.0-1 [54.3 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy/main amd64 libwacom9 amd64 2.2.0-1 [22.0 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libinput-bin amd64 1.20.0-1ubuntu0.4 [20.4 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libinput10 amd64 1.20.0-1ubuntu0.4 [131 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libmd4c0 amd64 0.4.8-1 [42.0 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libqt5dbus5 amd64 5.15.3+dfsg-2ubuntu0.2 [222 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libqt5network5 amd64 5.15.3+dfsg-2ubuntu0.2 [731 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-icccm4 amd64 0.4.1-1.1build2 [11.5 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-util1 amd64 0.4.0-1build2 [11.4 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-image0 amd64 0.4.0-2 [11.5 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-keysyms1 amd64 0.4.0-1build3 [8,746 B]
# Get:20 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-render-util0 amd64 0.3.9-1build3 [10.3 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-xinerama0 amd64 1.14-3ubuntu3 [5,414 B]
# Get:22 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-xinput0 amd64 1.14-3ubuntu3 [34.3 kB]
# Get:23 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-xkb1 amd64 1.14-3ubuntu3 [32.8 kB]
# Get:24 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxkbcommon-x11-0 amd64 1.4.0-1 [14.4 kB]
# Get:25 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libqt5gui5 amd64 5.15.3+dfsg-2ubuntu0.2 [3,722 kB]
# Get:26 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libqt5widgets5 amd64 5.15.3+dfsg-2ubuntu0.2 [2,561 kB]
# Get:27 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libqt5svg5 amd64 5.15.3-1 [149 kB]
# Get:28 http://archive.ubuntu.com/ubuntu jammy/main amd64 python3-yaml amd64 5.4.1-1ubuntu1 [129 kB]
# Get:29 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 udev amd64 249.11-0ubuntu3.22 [1,559 kB]
# Get:30 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 dbus-x11 amd64 1.12.20-2ubuntu4.1 [23.0 kB]
# Get:31 http://archive.ubuntu.com/ubuntu jammy/main amd64 desktop-file-utils amd64 0.26-1ubuntu3 [55.9 kB]
# Get:32 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-dejavu-core all 2.37-2build1 [1,041 kB]
# Get:33 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-dejavu-extra all 2.37-2build1 [2,041 kB]
# Get:34 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-dejavu all 2.37-2build1 [3,192 B]
# Get:35 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-noto-core all 20201225-1build1 [12.2 MB]
# Get:36 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-noto all 20201225-1build1 [16.8 kB]
# Get:37 http://archive.ubuntu.com/ubuntu jammy/universe amd64 kwayland-data all 4:5.92.0-0ubuntu1 [4,638 B]
# Get:38 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libdbusmenu-qt5-2 amd64 0.9.3+16.04.20160218-2build1 [78.6 kB]
# Get:39 http://archive.ubuntu.com/ubuntu jammy/main amd64 libencode-locale-perl all 1.05-1.1 [11.8 kB]
# Get:40 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libexif12 amd64 0.6.24-1ubuntu0.22.04.1 [92.7 kB]
# Get:41 http://archive.ubuntu.com/ubuntu jammy/main amd64 libipc-system-simple-perl all 1.30-1 [23.2 kB]
# Get:42 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfile-basedir-perl all 0.09-1 [15.7 kB]
# Get:43 http://archive.ubuntu.com/ubuntu jammy/main amd64 liburi-perl all 5.10-1 [78.8 kB]
# Get:44 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfile-desktopentry-perl all 0.22-2 [17.8 kB]
# Get:45 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfile-mimeinfo-perl all 0.31-1 [43.5 kB]
# Get:46 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libfm-extra4 amd64 1.3.2-1 [14.5 kB]
# Get:47 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libmenu-cache-bin amd64 1.1.0-1.1 [29.7 kB]
# Get:48 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libmenu-cache3 amd64 1.1.0-1.1 [13.9 kB]
# Get:49 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libqt5x11extras5 amd64 5.15.3-1 [10.9 kB]
# Get:50 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libfm-qt9 amd64 0.17.1-0ubuntu2 [450 kB]
# Get:51 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libid3tag0 amd64 0.15.1b-14 [31.3 kB]
# Get:52 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libimlib2 amd64 1.7.4-1build1 [195 kB]
# Get:53 http://archive.ubuntu.com/ubuntu jammy/main amd64 libplist3 amd64 2.2.0-6build2 [32.1 kB]
# Get:54 http://archive.ubuntu.com/ubuntu jammy/main amd64 libusbmuxd6 amd64 2.0.2-3build2 [20.4 kB]
# Get:55 http://archive.ubuntu.com/ubuntu jammy/main amd64 libimobiledevice6 amd64 1.3.0-6build3 [71.1 kB]
# Get:56 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libkf5screen7 amd64 4:5.24.4-0ubuntu1 [85.0 kB]
# Get:57 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libkf5waylandclient5 amd64 4:5.92.0-0ubuntu1 [226 kB]
# Get:58 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libkf5screen-bin amd64 4:5.24.4-0ubuntu1 [135 kB]
# Get:59 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libkf5solid5-data all 5.92.0-0ubuntu1 [101 kB]
# Get:60 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libqt5xml5 amd64 5.15.3+dfsg-2ubuntu0.2 [124 kB]
# Get:61 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libkf5solid5 amd64 5.92.0-0ubuntu1 [209 kB]
# Get:62 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libkf5windowsystem-data all 5.92.0-0ubuntu1 [10.6 kB]
# Get:63 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-res0 amd64 1.14-3ubuntu3 [6,704 B]
# Get:64 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libkf5windowsystem5 amd64 5.92.0-0ubuntu1 [150 kB]
# Get:65 http://archive.ubuntu.com/ubuntu jammy/universe amd64 liblxqt-globalkeys0 amd64 0.17.0-0ubuntu1 [26.6 kB]
# Get:66 http://archive.ubuntu.com/ubuntu jammy/universe amd64 liblxqt-globalkeys-ui0 amd64 0.17.0-0ubuntu1 [8,890 B]
# Get:67 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libqt5xdgiconloader3 amd64 3.7.1-0ubuntu2 [31.4 kB]
# Get:68 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libqt5xdg3 amd64 3.7.1-0ubuntu2 [101 kB]
# Get:69 http://archive.ubuntu.com/ubuntu jammy/universe amd64 liblxqt0 amd64 0.17.0-0ubuntu1 [103 kB]
# Get:70 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libmuparser2v5 amd64 2.2.6.1+dfsg-1build1 [102 kB]
# Get:71 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libobt2v5 amd64 3.6.1-10 [35.5 kB]
# Get:72 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libobrender32v5 amd64 3.6.1-10 [42.4 kB]
# Get:73 http://archive.ubuntu.com/ubuntu jammy/universe amd64 qtermwidget5-data all 0.17.0-0ubuntu1 [29.0 kB]
# Get:74 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libutf8proc2 amd64 2.7.0-3 [73.9 kB]
# Get:75 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libqtermwidget5-0 amd64 0.17.0-0ubuntu1 [149 kB]
# Get:76 http://archive.ubuntu.com/ubuntu jammy/main amd64 libstartup-notification0 amd64 0.12-6build2 [19.5 kB]
# Get:77 http://archive.ubuntu.com/ubuntu jammy/main amd64 libstatgrab10 amd64 0.92.1-1build1 [38.0 kB]
# Get:78 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libsysstat-qt5-0 amd64 0.4.6-1 [26.1 kB]
# Get:79 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcomposite1 amd64 1:0.4.5-1build2 [7,192 B]
# Get:80 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcvt0 amd64 0.1.1-3 [5,494 B]
# Get:81 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxtst6 amd64 2:1.2.3-1build4 [13.4 kB]
# Get:82 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxxf86dga1 amd64 2:1.1.5-0ubuntu3 [12.6 kB]
# Get:83 http://archive.ubuntu.com/ubuntu jammy/universe amd64 lxmenu-data all 0.1.5-2.1 [48.3 kB]
# Get:84 http://archive.ubuntu.com/ubuntu jammy/universe amd64 lxqt-config amd64 0.17.1-0ubuntu1 [288 kB]
# Get:85 http://archive.ubuntu.com/ubuntu jammy/main amd64 x11-utils amd64 7.7+5build2 [206 kB]
# Get:86 http://archive.ubuntu.com/ubuntu jammy/universe amd64 lxqt-system-theme all 0.17.0-0ubuntu1 [58.4 kB]
# Get:87 http://archive.ubuntu.com/ubuntu jammy/universe amd64 lxqt-themes all 0.17.0-0ubuntu1 [2,873 kB]
# Get:88 http://archive.ubuntu.com/ubuntu jammy/universe amd64 lxqt-notificationd amd64 0.17.0-0ubuntu1 [61.7 kB]
# Get:89 http://archive.ubuntu.com/ubuntu jammy/universe amd64 lxqt-globalkeys amd64 0.17.0-0ubuntu1 [152 kB]
# Get:90 http://archive.ubuntu.com/ubuntu jammy/universe amd64 lxqt-qtplugin amd64 0.17.0-0ubuntu3 [37.1 kB]
# Get:91 http://archive.ubuntu.com/ubuntu jammy/universe amd64 lxqt-session amd64 0.17.1-0ubuntu1 [118 kB]
# Get:92 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libpolkit-qt5-1-1 amd64 0.114.0-2 [62.3 kB]
# Get:93 http://archive.ubuntu.com/ubuntu jammy/universe amd64 lxqt-policykit amd64 0.17.0-0ubuntu1 [20.1 kB]
# Get:94 http://archive.ubuntu.com/ubuntu jammy/universe amd64 lxqt-panel amd64 0.17.1-0ubuntu1 [555 kB]
# Get:95 http://archive.ubuntu.com/ubuntu jammy/universe amd64 lxqt-runner amd64 0.17.0-0ubuntu1 [76.2 kB]
# Get:96 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 lxqt-sudo amd64 0.17.0-0ubuntu1.1 [23.1 kB]
# Get:97 http://archive.ubuntu.com/ubuntu jammy/universe amd64 pcmanfm-qt amd64 0.17.0-0ubuntu1 [205 kB]
# Get:98 http://archive.ubuntu.com/ubuntu jammy/universe amd64 qterminal amd64 0.17.0-0ubuntu1 [138 kB]
# Get:99 http://archive.ubuntu.com/ubuntu jammy/universe amd64 lxqt-core all 30ubuntu1 [3,400 B]
# Get:100 http://archive.ubuntu.com/ubuntu jammy/universe amd64 openbox amd64 3.6.1-10 [311 kB]
# Get:101 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 python3-problem-report all 2.20.11-0ubuntu82.10 [11.4 kB]
# Get:102 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 python3-apport all 2.20.11-0ubuntu82.10 [89.0 kB]
# Get:103 http://archive.ubuntu.com/ubuntu jammy/main amd64 x11-apps amd64 7.7+8build2 [719 kB]
# Get:104 http://archive.ubuntu.com/ubuntu jammy/main amd64 x11-session-utils amd64 7.7+4build2 [73.0 kB]
# Get:105 http://archive.ubuntu.com/ubuntu jammy/main amd64 x11-xserver-utils amd64 7.7+9build1 [170 kB]
# Get:106 http://archive.ubuntu.com/ubuntu jammy/universe amd64 xclip amd64 0.13-2 [18.3 kB]
# Get:107 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-encodings all 1:1.0.5-0ubuntu2 [578 kB]
# Get:108 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-utils amd64 1:7.7+6build2 [94.6 kB]
# Get:109 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-base all 1:1.0.5 [5,896 kB]
# Get:110 http://archive.ubuntu.com/ubuntu jammy/main amd64 xinit amd64 1.4.1-0ubuntu4 [18.0 kB]
# Get:111 http://archive.ubuntu.com/ubuntu jammy/main amd64 xinput amd64 1.6.3-1build2 [29.2 kB]
# Get:112 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 xserver-xorg-core amd64 2:21.1.4-2ubuntu1.7~22.04.16 [1,478 kB]
# Get:113 http://archive.ubuntu.com/ubuntu jammy/main amd64 xserver-xorg-input-libinput amd64 1.2.1-1 [38.7 kB]
# Get:114 http://archive.ubuntu.com/ubuntu jammy/main amd64 xserver-xorg-input-all amd64 1:7.7+23ubuntu2 [4,058 B]
# Get:115 http://archive.ubuntu.com/ubuntu jammy/main amd64 xserver-xorg amd64 1:7.7+23ubuntu2 [66.7 kB]
# Get:116 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglu1-mesa amd64 9.0.2-1 [145 kB]
# Get:117 http://archive.ubuntu.com/ubuntu jammy/main amd64 xorg-docs-core all 1:1.7.1-1.2 [41.7 kB]
# Get:118 http://archive.ubuntu.com/ubuntu jammy/main amd64 xorg amd64 1:7.7+23ubuntu2 [2,890 B]
# Get:119 http://archive.ubuntu.com/ubuntu jammy/universe amd64 xsel amd64 1.2.0+git9bfc13d.20180109-3 [20.5 kB]
# Get:120 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libxdo3 amd64 1:3.20160805.1-4 [21.0 kB]
# Get:121 http://archive.ubuntu.com/ubuntu jammy/universe amd64 xdotool amd64 1:3.20160805.1-4 [41.5 kB]
# Fetched 45.2 MB in 8s (5,518 kB/s)
# Extracting templates from packages: 100%
# Preconfiguring packages ...
# Selecting previously unselected package liblocale-gettext-perl.
# (Reading database ... 122579 files and directories currently installed.)
# Preparing to unpack .../0-liblocale-gettext-perl_1.07-4build3_amd64.deb ...
# Unpacking liblocale-gettext-perl (1.07-4build3) ...
# Selecting previously unselected package keyboard-configuration.
# Preparing to unpack .../1-keyboard-configuration_1.205ubuntu3_all.deb ...
# Unpacking keyboard-configuration (1.205ubuntu3) ...
# Selecting previously unselected package libdouble-conversion3:amd64.
# Preparing to unpack .../2-libdouble-conversion3_3.1.7-4_amd64.deb ...
# Unpacking libdouble-conversion3:amd64 (3.1.7-4) ...
# Selecting previously unselected package libqt5core5a:amd64.
# Preparing to unpack .../3-libqt5core5a_5.15.3+dfsg-2ubuntu0.2_amd64.deb ...
# Unpacking libqt5core5a:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Selecting previously unselected package libevdev2:amd64.
# Preparing to unpack .../4-libevdev2_1.12.1+dfsg-1_amd64.deb ...
# Unpacking libevdev2:amd64 (1.12.1+dfsg-1) ...
# Selecting previously unselected package libmtdev1:amd64.
# Preparing to unpack .../5-libmtdev1_1.1.6-1build4_amd64.deb ...
# Unpacking libmtdev1:amd64 (1.1.6-1build4) ...
# Preparing to unpack .../6-libudev1_249.11-0ubuntu3.22_amd64.deb ...
# Unpacking libudev1:amd64 (249.11-0ubuntu3.22) over (249.11-0ubuntu3.12) ...
# Setting up libudev1:amd64 (249.11-0ubuntu3.22) ...
# Selecting previously unselected package libgudev-1.0-0:amd64.
# (Reading database ... 122641 files and directories currently installed.)
# Preparing to unpack .../000-libgudev-1.0-0_1%3a237-2build1_amd64.deb ...
# Unpacking libgudev-1.0-0:amd64 (1:237-2build1) ...
# Selecting previously unselected package libwacom-common.
# Preparing to unpack .../001-libwacom-common_2.2.0-1_all.deb ...
# Unpacking libwacom-common (2.2.0-1) ...
# Selecting previously unselected package libwacom9:amd64.
# Preparing to unpack .../002-libwacom9_2.2.0-1_amd64.deb ...
# Unpacking libwacom9:amd64 (2.2.0-1) ...
# Selecting previously unselected package libinput-bin.
# Preparing to unpack .../003-libinput-bin_1.20.0-1ubuntu0.4_amd64.deb ...
# Unpacking libinput-bin (1.20.0-1ubuntu0.4) ...
# Selecting previously unselected package libinput10:amd64.
# Preparing to unpack .../004-libinput10_1.20.0-1ubuntu0.4_amd64.deb ...
# Unpacking libinput10:amd64 (1.20.0-1ubuntu0.4) ...
# Selecting previously unselected package libmd4c0:amd64.
# Preparing to unpack .../005-libmd4c0_0.4.8-1_amd64.deb ...
# Unpacking libmd4c0:amd64 (0.4.8-1) ...
# Selecting previously unselected package libqt5dbus5:amd64.
# Preparing to unpack .../006-libqt5dbus5_5.15.3+dfsg-2ubuntu0.2_amd64.deb ...
# Unpacking libqt5dbus5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Selecting previously unselected package libqt5network5:amd64.
# Preparing to unpack .../007-libqt5network5_5.15.3+dfsg-2ubuntu0.2_amd64.deb ...
# Unpacking libqt5network5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Selecting previously unselected package libxcb-icccm4:amd64.
# Preparing to unpack .../008-libxcb-icccm4_0.4.1-1.1build2_amd64.deb ...
# Unpacking libxcb-icccm4:amd64 (0.4.1-1.1build2) ...
# Selecting previously unselected package libxcb-util1:amd64.
# Preparing to unpack .../009-libxcb-util1_0.4.0-1build2_amd64.deb ...
# Unpacking libxcb-util1:amd64 (0.4.0-1build2) ...
# Selecting previously unselected package libxcb-image0:amd64.
# Preparing to unpack .../010-libxcb-image0_0.4.0-2_amd64.deb ...
# Unpacking libxcb-image0:amd64 (0.4.0-2) ...
# Selecting previously unselected package libxcb-keysyms1:amd64.
# Preparing to unpack .../011-libxcb-keysyms1_0.4.0-1build3_amd64.deb ...
# Unpacking libxcb-keysyms1:amd64 (0.4.0-1build3) ...
# Selecting previously unselected package libxcb-render-util0:amd64.
# Preparing to unpack .../012-libxcb-render-util0_0.3.9-1build3_amd64.deb ...
# Unpacking libxcb-render-util0:amd64 (0.3.9-1build3) ...
# Selecting previously unselected package libxcb-xinerama0:amd64.
# Preparing to unpack .../013-libxcb-xinerama0_1.14-3ubuntu3_amd64.deb ...
# Unpacking libxcb-xinerama0:amd64 (1.14-3ubuntu3) ...
# Selecting previously unselected package libxcb-xinput0:amd64.
# Preparing to unpack .../014-libxcb-xinput0_1.14-3ubuntu3_amd64.deb ...
# Unpacking libxcb-xinput0:amd64 (1.14-3ubuntu3) ...
# Selecting previously unselected package libxcb-xkb1:amd64.
# Preparing to unpack .../015-libxcb-xkb1_1.14-3ubuntu3_amd64.deb ...
# Unpacking libxcb-xkb1:amd64 (1.14-3ubuntu3) ...
# Selecting previously unselected package libxkbcommon-x11-0:amd64.
# Preparing to unpack .../016-libxkbcommon-x11-0_1.4.0-1_amd64.deb ...
# Unpacking libxkbcommon-x11-0:amd64 (1.4.0-1) ...
# Selecting previously unselected package libqt5gui5:amd64.
# Preparing to unpack .../017-libqt5gui5_5.15.3+dfsg-2ubuntu0.2_amd64.deb ...
# Unpacking libqt5gui5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Selecting previously unselected package libqt5widgets5:amd64.
# Preparing to unpack .../018-libqt5widgets5_5.15.3+dfsg-2ubuntu0.2_amd64.deb ...
# Unpacking libqt5widgets5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Selecting previously unselected package libqt5svg5:amd64.
# Preparing to unpack .../019-libqt5svg5_5.15.3-1_amd64.deb ...
# Unpacking libqt5svg5:amd64 (5.15.3-1) ...
# Selecting previously unselected package python3-yaml.
# Preparing to unpack .../020-python3-yaml_5.4.1-1ubuntu1_amd64.deb ...
# Unpacking python3-yaml (5.4.1-1ubuntu1) ...
# Selecting previously unselected package udev.
# Preparing to unpack .../021-udev_249.11-0ubuntu3.22_amd64.deb ...
# Unpacking udev (249.11-0ubuntu3.22) ...
# Selecting previously unselected package dbus-x11.
# Preparing to unpack .../022-dbus-x11_1.12.20-2ubuntu4.1_amd64.deb ...
# Unpacking dbus-x11 (1.12.20-2ubuntu4.1) ...
# Selecting previously unselected package desktop-file-utils.
# Preparing to unpack .../023-desktop-file-utils_0.26-1ubuntu3_amd64.deb ...
# Unpacking desktop-file-utils (0.26-1ubuntu3) ...
# Selecting previously unselected package fonts-dejavu-core.
# Preparing to unpack .../024-fonts-dejavu-core_2.37-2build1_all.deb ...
# Unpacking fonts-dejavu-core (2.37-2build1) ...
# Selecting previously unselected package fonts-dejavu-extra.
# Preparing to unpack .../025-fonts-dejavu-extra_2.37-2build1_all.deb ...
# Unpacking fonts-dejavu-extra (2.37-2build1) ...
# Selecting previously unselected package fonts-dejavu.
# Preparing to unpack .../026-fonts-dejavu_2.37-2build1_all.deb ...
# Unpacking fonts-dejavu (2.37-2build1) ...
# Selecting previously unselected package fonts-noto-core.
# Preparing to unpack .../027-fonts-noto-core_20201225-1build1_all.deb ...
# Unpacking fonts-noto-core (20201225-1build1) ...
# Selecting previously unselected package fonts-noto.
# Preparing to unpack .../028-fonts-noto_20201225-1build1_all.deb ...
# Unpacking fonts-noto (20201225-1build1) ...
# Selecting previously unselected package kwayland-data.
# Preparing to unpack .../029-kwayland-data_4%3a5.92.0-0ubuntu1_all.deb ...
# Unpacking kwayland-data (4:5.92.0-0ubuntu1) ...
# Selecting previously unselected package libdbusmenu-qt5-2:amd64.
# Preparing to unpack .../030-libdbusmenu-qt5-2_0.9.3+16.04.20160218-2build1_amd64.deb ...
# Unpacking libdbusmenu-qt5-2:amd64 (0.9.3+16.04.20160218-2build1) ...
# Selecting previously unselected package libencode-locale-perl.
# Preparing to unpack .../031-libencode-locale-perl_1.05-1.1_all.deb ...
# Unpacking libencode-locale-perl (1.05-1.1) ...
# Selecting previously unselected package libexif12:amd64.
# Preparing to unpack .../032-libexif12_0.6.24-1ubuntu0.22.04.1_amd64.deb ...
# Unpacking libexif12:amd64 (0.6.24-1ubuntu0.22.04.1) ...
# Selecting previously unselected package libipc-system-simple-perl.
# Preparing to unpack .../033-libipc-system-simple-perl_1.30-1_all.deb ...
# Unpacking libipc-system-simple-perl (1.30-1) ...
# Selecting previously unselected package libfile-basedir-perl.
# Preparing to unpack .../034-libfile-basedir-perl_0.09-1_all.deb ...
# Unpacking libfile-basedir-perl (0.09-1) ...
# Selecting previously unselected package liburi-perl.
# Preparing to unpack .../035-liburi-perl_5.10-1_all.deb ...
# Unpacking liburi-perl (5.10-1) ...
# Selecting previously unselected package libfile-desktopentry-perl.
# Preparing to unpack .../036-libfile-desktopentry-perl_0.22-2_all.deb ...
# Unpacking libfile-desktopentry-perl (0.22-2) ...
# Selecting previously unselected package libfile-mimeinfo-perl.
# Preparing to unpack .../037-libfile-mimeinfo-perl_0.31-1_all.deb ...
# Unpacking libfile-mimeinfo-perl (0.31-1) ...
# Selecting previously unselected package libfm-extra4:amd64.
# Preparing to unpack .../038-libfm-extra4_1.3.2-1_amd64.deb ...
# Unpacking libfm-extra4:amd64 (1.3.2-1) ...
# Selecting previously unselected package libmenu-cache-bin.
# Preparing to unpack .../039-libmenu-cache-bin_1.1.0-1.1_amd64.deb ...
# Unpacking libmenu-cache-bin (1.1.0-1.1) ...
# Selecting previously unselected package libmenu-cache3:amd64.
# Preparing to unpack .../040-libmenu-cache3_1.1.0-1.1_amd64.deb ...
# Unpacking libmenu-cache3:amd64 (1.1.0-1.1) ...
# Selecting previously unselected package libqt5x11extras5:amd64.
# Preparing to unpack .../041-libqt5x11extras5_5.15.3-1_amd64.deb ...
# Unpacking libqt5x11extras5:amd64 (5.15.3-1) ...
# Selecting previously unselected package libfm-qt9:amd64.
# Preparing to unpack .../042-libfm-qt9_0.17.1-0ubuntu2_amd64.deb ...
# Unpacking libfm-qt9:amd64 (0.17.1-0ubuntu2) ...
# Selecting previously unselected package libid3tag0:amd64.
# Preparing to unpack .../043-libid3tag0_0.15.1b-14_amd64.deb ...
# Unpacking libid3tag0:amd64 (0.15.1b-14) ...
# Selecting previously unselected package libimlib2:amd64.
# Preparing to unpack .../044-libimlib2_1.7.4-1build1_amd64.deb ...
# Unpacking libimlib2:amd64 (1.7.4-1build1) ...
# Selecting previously unselected package libplist3:amd64.
# Preparing to unpack .../045-libplist3_2.2.0-6build2_amd64.deb ...
# Unpacking libplist3:amd64 (2.2.0-6build2) ...
# Selecting previously unselected package libusbmuxd6:amd64.
# Preparing to unpack .../046-libusbmuxd6_2.0.2-3build2_amd64.deb ...
# Unpacking libusbmuxd6:amd64 (2.0.2-3build2) ...
# Selecting previously unselected package libimobiledevice6:amd64.
# Preparing to unpack .../047-libimobiledevice6_1.3.0-6build3_amd64.deb ...
# Unpacking libimobiledevice6:amd64 (1.3.0-6build3) ...
# Selecting previously unselected package libkf5screen7:amd64.
# Preparing to unpack .../048-libkf5screen7_4%3a5.24.4-0ubuntu1_amd64.deb ...
# Unpacking libkf5screen7:amd64 (4:5.24.4-0ubuntu1) ...
# Selecting previously unselected package libkf5waylandclient5:amd64.
# Preparing to unpack .../049-libkf5waylandclient5_4%3a5.92.0-0ubuntu1_amd64.deb ...
# Unpacking libkf5waylandclient5:amd64 (4:5.92.0-0ubuntu1) ...
# Selecting previously unselected package libkf5screen-bin.
# Preparing to unpack .../050-libkf5screen-bin_4%3a5.24.4-0ubuntu1_amd64.deb ...
# Unpacking libkf5screen-bin (4:5.24.4-0ubuntu1) ...
# Selecting previously unselected package libkf5solid5-data.
# Preparing to unpack .../051-libkf5solid5-data_5.92.0-0ubuntu1_all.deb ...
# Unpacking libkf5solid5-data (5.92.0-0ubuntu1) ...
# Selecting previously unselected package libqt5xml5:amd64.
# Preparing to unpack .../052-libqt5xml5_5.15.3+dfsg-2ubuntu0.2_amd64.deb ...
# Unpacking libqt5xml5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Selecting previously unselected package libkf5solid5:amd64.
# Preparing to unpack .../053-libkf5solid5_5.92.0-0ubuntu1_amd64.deb ...
# Unpacking libkf5solid5:amd64 (5.92.0-0ubuntu1) ...
# Selecting previously unselected package libkf5windowsystem-data.
# Preparing to unpack .../054-libkf5windowsystem-data_5.92.0-0ubuntu1_all.deb ...
# Unpacking libkf5windowsystem-data (5.92.0-0ubuntu1) ...
# Selecting previously unselected package libxcb-res0:amd64.
# Preparing to unpack .../055-libxcb-res0_1.14-3ubuntu3_amd64.deb ...
# Unpacking libxcb-res0:amd64 (1.14-3ubuntu3) ...
# Selecting previously unselected package libkf5windowsystem5:amd64.
# Preparing to unpack .../056-libkf5windowsystem5_5.92.0-0ubuntu1_amd64.deb ...
# Unpacking libkf5windowsystem5:amd64 (5.92.0-0ubuntu1) ...
# Selecting previously unselected package liblxqt-globalkeys0:amd64.
# Preparing to unpack .../057-liblxqt-globalkeys0_0.17.0-0ubuntu1_amd64.deb ...
# Unpacking liblxqt-globalkeys0:amd64 (0.17.0-0ubuntu1) ...
# Selecting previously unselected package liblxqt-globalkeys-ui0:amd64.
# Preparing to unpack .../058-liblxqt-globalkeys-ui0_0.17.0-0ubuntu1_amd64.deb ...
# Unpacking liblxqt-globalkeys-ui0:amd64 (0.17.0-0ubuntu1) ...
# Selecting previously unselected package libqt5xdgiconloader3:amd64.
# Preparing to unpack .../059-libqt5xdgiconloader3_3.7.1-0ubuntu2_amd64.deb ...
# Unpacking libqt5xdgiconloader3:amd64 (3.7.1-0ubuntu2) ...
# Selecting previously unselected package libqt5xdg3:amd64.
# Preparing to unpack .../060-libqt5xdg3_3.7.1-0ubuntu2_amd64.deb ...
# Unpacking libqt5xdg3:amd64 (3.7.1-0ubuntu2) ...
# Selecting previously unselected package liblxqt0.
# Preparing to unpack .../061-liblxqt0_0.17.0-0ubuntu1_amd64.deb ...
# Unpacking liblxqt0 (0.17.0-0ubuntu1) ...
# Selecting previously unselected package libmuparser2v5:amd64.
# Preparing to unpack .../062-libmuparser2v5_2.2.6.1+dfsg-1build1_amd64.deb ...
# Unpacking libmuparser2v5:amd64 (2.2.6.1+dfsg-1build1) ...
# Selecting previously unselected package libobt2v5.
# Preparing to unpack .../063-libobt2v5_3.6.1-10_amd64.deb ...
# Unpacking libobt2v5 (3.6.1-10) ...
# Selecting previously unselected package libobrender32v5.
# Preparing to unpack .../064-libobrender32v5_3.6.1-10_amd64.deb ...
# Unpacking libobrender32v5 (3.6.1-10) ...
# Selecting previously unselected package qtermwidget5-data.
# Preparing to unpack .../065-qtermwidget5-data_0.17.0-0ubuntu1_all.deb ...
# Unpacking qtermwidget5-data (0.17.0-0ubuntu1) ...
# Selecting previously unselected package libutf8proc2:amd64.
# Preparing to unpack .../066-libutf8proc2_2.7.0-3_amd64.deb ...
# Unpacking libutf8proc2:amd64 (2.7.0-3) ...
# Selecting previously unselected package libqtermwidget5-0:amd64.
# Preparing to unpack .../067-libqtermwidget5-0_0.17.0-0ubuntu1_amd64.deb ...
# Unpacking libqtermwidget5-0:amd64 (0.17.0-0ubuntu1) ...
# Selecting previously unselected package libstartup-notification0:amd64.
# Preparing to unpack .../068-libstartup-notification0_0.12-6build2_amd64.deb ...
# Unpacking libstartup-notification0:amd64 (0.12-6build2) ...
# Selecting previously unselected package libstatgrab10.
# Preparing to unpack .../069-libstatgrab10_0.92.1-1build1_amd64.deb ...
# Unpacking libstatgrab10 (0.92.1-1build1) ...
# Selecting previously unselected package libsysstat-qt5-0:amd64.
# Preparing to unpack .../070-libsysstat-qt5-0_0.4.6-1_amd64.deb ...
# Unpacking libsysstat-qt5-0:amd64 (0.4.6-1) ...
# Selecting previously unselected package libxcomposite1:amd64.
# Preparing to unpack .../071-libxcomposite1_1%3a0.4.5-1build2_amd64.deb ...
# Unpacking libxcomposite1:amd64 (1:0.4.5-1build2) ...
# Selecting previously unselected package libxcvt0:amd64.
# Preparing to unpack .../072-libxcvt0_0.1.1-3_amd64.deb ...
# Unpacking libxcvt0:amd64 (0.1.1-3) ...
# Selecting previously unselected package libxtst6:amd64.
# Preparing to unpack .../073-libxtst6_2%3a1.2.3-1build4_amd64.deb ...
# Unpacking libxtst6:amd64 (2:1.2.3-1build4) ...
# Selecting previously unselected package libxxf86dga1:amd64.
# Preparing to unpack .../074-libxxf86dga1_2%3a1.1.5-0ubuntu3_amd64.deb ...
# Unpacking libxxf86dga1:amd64 (2:1.1.5-0ubuntu3) ...
# Selecting previously unselected package lxmenu-data.
# Preparing to unpack .../075-lxmenu-data_0.1.5-2.1_all.deb ...
# Unpacking lxmenu-data (0.1.5-2.1) ...
# Selecting previously unselected package lxqt-config.
# Preparing to unpack .../076-lxqt-config_0.17.1-0ubuntu1_amd64.deb ...
# Unpacking lxqt-config (0.17.1-0ubuntu1) ...
# Selecting previously unselected package x11-utils.
# Preparing to unpack .../077-x11-utils_7.7+5build2_amd64.deb ...
# Unpacking x11-utils (7.7+5build2) ...
# Selecting previously unselected package lxqt-system-theme.
# Preparing to unpack .../078-lxqt-system-theme_0.17.0-0ubuntu1_all.deb ...
# Unpacking lxqt-system-theme (0.17.0-0ubuntu1) ...
# Selecting previously unselected package lxqt-themes.
# Preparing to unpack .../079-lxqt-themes_0.17.0-0ubuntu1_all.deb ...
# Unpacking lxqt-themes (0.17.0-0ubuntu1) ...
# Selecting previously unselected package lxqt-notificationd.
# Preparing to unpack .../080-lxqt-notificationd_0.17.0-0ubuntu1_amd64.deb ...
# Unpacking lxqt-notificationd (0.17.0-0ubuntu1) ...
# Selecting previously unselected package lxqt-globalkeys.
# Preparing to unpack .../081-lxqt-globalkeys_0.17.0-0ubuntu1_amd64.deb ...
# Unpacking lxqt-globalkeys (0.17.0-0ubuntu1) ...
# Selecting previously unselected package lxqt-qtplugin:amd64.
# Preparing to unpack .../082-lxqt-qtplugin_0.17.0-0ubuntu3_amd64.deb ...
# Unpacking lxqt-qtplugin:amd64 (0.17.0-0ubuntu3) ...
# Selecting previously unselected package lxqt-session.
# Preparing to unpack .../083-lxqt-session_0.17.1-0ubuntu1_amd64.deb ...
# Unpacking lxqt-session (0.17.1-0ubuntu1) ...
# Selecting previously unselected package libpolkit-qt5-1-1:amd64.
# Preparing to unpack .../084-libpolkit-qt5-1-1_0.114.0-2_amd64.deb ...
# Unpacking libpolkit-qt5-1-1:amd64 (0.114.0-2) ...
# Selecting previously unselected package lxqt-policykit.
# Preparing to unpack .../085-lxqt-policykit_0.17.0-0ubuntu1_amd64.deb ...
# Unpacking lxqt-policykit (0.17.0-0ubuntu1) ...
# Selecting previously unselected package lxqt-panel.
# Preparing to unpack .../086-lxqt-panel_0.17.1-0ubuntu1_amd64.deb ...
# Unpacking lxqt-panel (0.17.1-0ubuntu1) ...
# Selecting previously unselected package lxqt-runner.
# Preparing to unpack .../087-lxqt-runner_0.17.0-0ubuntu1_amd64.deb ...
# Unpacking lxqt-runner (0.17.0-0ubuntu1) ...
# Selecting previously unselected package lxqt-sudo.
# Preparing to unpack .../088-lxqt-sudo_0.17.0-0ubuntu1.1_amd64.deb ...
# Unpacking lxqt-sudo (0.17.0-0ubuntu1.1) ...
# Selecting previously unselected package pcmanfm-qt.
# Preparing to unpack .../089-pcmanfm-qt_0.17.0-0ubuntu1_amd64.deb ...
# Unpacking pcmanfm-qt (0.17.0-0ubuntu1) ...
# Selecting previously unselected package qterminal.
# Preparing to unpack .../090-qterminal_0.17.0-0ubuntu1_amd64.deb ...
# Unpacking qterminal (0.17.0-0ubuntu1) ...
# Selecting previously unselected package lxqt-core.
# Preparing to unpack .../091-lxqt-core_30ubuntu1_all.deb ...
# Unpacking lxqt-core (30ubuntu1) ...
# Selecting previously unselected package openbox.
# Preparing to unpack .../092-openbox_3.6.1-10_amd64.deb ...
# Unpacking openbox (3.6.1-10) ...
# Selecting previously unselected package python3-problem-report.
# Preparing to unpack .../093-python3-problem-report_2.20.11-0ubuntu82.10_all.deb ...
# Unpacking python3-problem-report (2.20.11-0ubuntu82.10) ...
# Selecting previously unselected package python3-apport.
# Preparing to unpack .../094-python3-apport_2.20.11-0ubuntu82.10_all.deb ...
# Unpacking python3-apport (2.20.11-0ubuntu82.10) ...
# Selecting previously unselected package x11-apps.
# Preparing to unpack .../095-x11-apps_7.7+8build2_amd64.deb ...
# Unpacking x11-apps (7.7+8build2) ...
# Selecting previously unselected package x11-session-utils.
# Preparing to unpack .../096-x11-session-utils_7.7+4build2_amd64.deb ...
# Unpacking x11-session-utils (7.7+4build2) ...
# Selecting previously unselected package x11-xserver-utils.
# Preparing to unpack .../097-x11-xserver-utils_7.7+9build1_amd64.deb ...
# Unpacking x11-xserver-utils (7.7+9build1) ...
# Selecting previously unselected package xclip.
# Preparing to unpack .../098-xclip_0.13-2_amd64.deb ...
# Unpacking xclip (0.13-2) ...
# Selecting previously unselected package xfonts-encodings.
# Preparing to unpack .../099-xfonts-encodings_1%3a1.0.5-0ubuntu2_all.deb ...
# Unpacking xfonts-encodings (1:1.0.5-0ubuntu2) ...
# Selecting previously unselected package xfonts-utils.
# Preparing to unpack .../100-xfonts-utils_1%3a7.7+6build2_amd64.deb ...
# Unpacking xfonts-utils (1:7.7+6build2) ...
# Selecting previously unselected package xfonts-base.
# Preparing to unpack .../101-xfonts-base_1%3a1.0.5_all.deb ...
# Unpacking xfonts-base (1:1.0.5) ...
# Selecting previously unselected package xinit.
# Preparing to unpack .../102-xinit_1.4.1-0ubuntu4_amd64.deb ...
# Unpacking xinit (1.4.1-0ubuntu4) ...
# Selecting previously unselected package xinput.
# Preparing to unpack .../103-xinput_1.6.3-1build2_amd64.deb ...
# Unpacking xinput (1.6.3-1build2) ...
# Selecting previously unselected package xserver-xorg-core.
# Preparing to unpack .../104-xserver-xorg-core_2%3a21.1.4-2ubuntu1.7~22.04.16_amd64.deb ...
# Unpacking xserver-xorg-core (2:21.1.4-2ubuntu1.7~22.04.16) ...
# Selecting previously unselected package xserver-xorg-input-libinput.
# Preparing to unpack .../105-xserver-xorg-input-libinput_1.2.1-1_amd64.deb ...
# Unpacking xserver-xorg-input-libinput (1.2.1-1) ...
# Selecting previously unselected package xserver-xorg-input-all.
# Preparing to unpack .../106-xserver-xorg-input-all_1%3a7.7+23ubuntu2_amd64.deb ...
# Unpacking xserver-xorg-input-all (1:7.7+23ubuntu2) ...
# Selecting previously unselected package xserver-xorg.
# Preparing to unpack .../107-xserver-xorg_1%3a7.7+23ubuntu2_amd64.deb ...
# Unpacking xserver-xorg (1:7.7+23ubuntu2) ...
# Selecting previously unselected package libglu1-mesa:amd64.
# Preparing to unpack .../108-libglu1-mesa_9.0.2-1_amd64.deb ...
# Unpacking libglu1-mesa:amd64 (9.0.2-1) ...
# Selecting previously unselected package xorg-docs-core.
# Preparing to unpack .../109-xorg-docs-core_1%3a1.7.1-1.2_all.deb ...
# Unpacking xorg-docs-core (1:1.7.1-1.2) ...
# Selecting previously unselected package xorg.
# Preparing to unpack .../110-xorg_1%3a7.7+23ubuntu2_amd64.deb ...
# Unpacking xorg (1:7.7+23ubuntu2) ...
# Selecting previously unselected package xsel.
# Preparing to unpack .../111-xsel_1.2.0+git9bfc13d.20180109-3_amd64.deb ...
# Unpacking xsel (1.2.0+git9bfc13d.20180109-3) ...
# Selecting previously unselected package libxdo3:amd64.
# Preparing to unpack .../112-libxdo3_1%3a3.20160805.1-4_amd64.deb ...
# Unpacking libxdo3:amd64 (1:3.20160805.1-4) ...
# Selecting previously unselected package xdotool.
# Preparing to unpack .../113-xdotool_1%3a3.20160805.1-4_amd64.deb ...
# Unpacking xdotool (1:3.20160805.1-4) ...
# Setting up xsel (1.2.0+git9bfc13d.20180109-3) ...
# Setting up xinit (1.4.1-0ubuntu4) ...
# Setting up libxcb-res0:amd64 (1.14-3ubuntu3) ...
# Setting up libdouble-conversion3:amd64 (3.1.7-4) ...
# Setting up desktop-file-utils (0.26-1ubuntu3) ...
# Setting up libplist3:amd64 (2.2.0-6build2) ...
# Setting up libfm-extra4:amd64 (1.3.2-1) ...
# Setting up libxcb-xinput0:amd64 (1.14-3ubuntu3) ...
# Setting up libkf5solid5-data (5.92.0-0ubuntu1) ...
# Setting up python3-problem-report (2.20.11-0ubuntu82.10) ...
# Setting up libxtst6:amd64 (2:1.2.3-1build4) ...
# Setting up libutf8proc2:amd64 (2.7.0-3) ...
# Setting up libxcb-keysyms1:amd64 (0.4.0-1build3) ...
# Setting up libxxf86dga1:amd64 (2:1.1.5-0ubuntu3) ...
# Setting up libkf5windowsystem-data (5.92.0-0ubuntu1) ...
# Setting up x11-apps (7.7+8build2) ...
# Setting up libxcb-render-util0:amd64 (0.3.9-1build3) ...
# Setting up python3-yaml (5.4.1-1ubuntu1) ...
# Setting up libencode-locale-perl (1.05-1.1) ...
# Setting up xinput (1.6.3-1build2) ...
# Setting up libxcb-icccm4:amd64 (0.4.1-1.1build2) ...
# Setting up x11-xserver-utils (7.7+9build1) ...
# Setting up libxcb-util1:amd64 (0.4.0-1build2) ...
# Setting up python3-apport (2.20.11-0ubuntu82.10) ...
# Setting up libxcb-xkb1:amd64 (1.14-3ubuntu3) ...
# Setting up libxcb-image0:amd64 (0.4.0-2) ...
# Setting up lxmenu-data (0.1.5-2.1) ...
# Setting up libxdo3:amd64 (1:3.20160805.1-4) ...
# Setting up libid3tag0:amd64 (0.15.1b-14) ...
# Setting up xorg-docs-core (1:1.7.1-1.2) ...
# Setting up libxcb-xinerama0:amd64 (1.14-3ubuntu3) ...
# Setting up libipc-system-simple-perl (1.30-1) ...
# Setting up xfonts-encodings (1:1.0.5-0ubuntu2) ...
# Setting up libexif12:amd64 (0.6.24-1ubuntu0.22.04.1) ...
# Setting up libxkbcommon-x11-0:amd64 (1.4.0-1) ...
# Setting up udev (249.11-0ubuntu3.22) ...
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of start.
# Setting up xclip (0.13-2) ...
# Setting up libobt2v5 (3.6.1-10) ...
# Setting up libimlib2:amd64 (1.7.4-1build1) ...
# Setting up fonts-dejavu-core (2.37-2build1) ...
# Setting up qtermwidget5-data (0.17.0-0ubuntu1) ...
# Setting up libqt5core5a:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up libmtdev1:amd64 (1.1.6-1build4) ...
# Setting up fonts-dejavu-extra (2.37-2build1) ...
# Setting up libusbmuxd6:amd64 (2.0.2-3build2) ...
# Setting up dbus-x11 (1.12.20-2ubuntu4.1) ...
# Setting up libqt5dbus5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up libstatgrab10 (0.92.1-1build1) ...
# Setting up libxcvt0:amd64 (0.1.1-3) ...
# Setting up libmd4c0:amd64 (0.4.8-1) ...
# Setting up x11-session-utils (7.7+4build2) ...
# Setting up libglu1-mesa:amd64 (9.0.2-1) ...
# Setting up libobrender32v5 (3.6.1-10) ...
# Setting up libmuparser2v5:amd64 (2.2.6.1+dfsg-1build1) ...
# Setting up libmenu-cache-bin (1.1.0-1.1) ...
# Setting up libimobiledevice6:amd64 (1.3.0-6build3) ...
# Setting up libxcomposite1:amd64 (1:0.4.5-1build2) ...
# Setting up libevdev2:amd64 (1.12.1+dfsg-1) ...
# Setting up fonts-noto-core (20201225-1build1) ...
# Setting up liburi-perl (5.10-1) ...
# Setting up liblocale-gettext-perl (1.07-4build3) ...
# Setting up libgudev-1.0-0:amd64 (1:237-2build1) ...
# Setting up kwayland-data (4:5.92.0-0ubuntu1) ...
# Setting up liblxqt-globalkeys0:amd64 (0.17.0-0ubuntu1) ...
# Setting up libwacom-common (2.2.0-1) ...
# Setting up libstartup-notification0:amd64 (0.12-6build2) ...
# Setting up fonts-dejavu (2.37-2build1) ...
# Setting up libfile-basedir-perl (0.09-1) ...
# Setting up xdotool (1:3.20160805.1-4) ...
# Setting up libwacom9:amd64 (2.2.0-1) ...
# Setting up fonts-noto (20201225-1build1) ...
# Setting up xfonts-utils (1:7.7+6build2) ...
# Setting up libqt5network5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up libsysstat-qt5-0:amd64 (0.4.6-1) ...
# Setting up libinput-bin (1.20.0-1ubuntu0.4) ...
# Setting up libqt5xml5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up xfonts-base (1:1.0.5) ...
# Setting up openbox (3.6.1-10) ...
# update-alternatives: using /usr/bin/openbox to provide /usr/bin/x-window-manager (x-window-manager) in auto mode
# update-alternatives: using /usr/bin/openbox-session to provide /usr/bin/x-session-manager (x-session-manager) in auto mode
# Setting up libfile-desktopentry-perl (0.22-2) ...
# Setting up x11-utils (7.7+5build2) ...
# Setting up libmenu-cache3:amd64 (1.1.0-1.1) ...
# Setting up keyboard-configuration (1.205ubuntu3) ...
# Your console font configuration will be updated the next time your system
# boots. If you want to update it now, run 'setupcon' from a virtual console.
# Setting up libinput10:amd64 (1.20.0-1ubuntu0.4) ...
# Setting up libfile-mimeinfo-perl (0.31-1) ...
# Setting up libqt5gui5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up xserver-xorg-core (2:21.1.4-2ubuntu1.7~22.04.16) ...
# Setting up libqt5widgets5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up libqtermwidget5-0:amd64 (0.17.0-0ubuntu1) ...
# Setting up libkf5waylandclient5:amd64 (4:5.92.0-0ubuntu1) ...
# Setting up lxqt-system-theme (0.17.0-0ubuntu1) ...
# ...
# Selecting previously unselected package libfribidi-dev:amd64.
# Preparing to unpack .../16-libfribidi-dev_1.0.8-2ubuntu3.1_amd64.deb ...
# Unpacking libfribidi-dev:amd64 (1.0.8-2ubuntu3.1) ...
# Selecting previously unselected package libgpg-error-dev.
# Preparing to unpack .../17-libgpg-error-dev_1.43-3_amd64.deb ...
# Unpacking libgpg-error-dev (1.43-3) ...
# Selecting previously unselected package libgcrypt20-dev.
# Preparing to unpack .../18-libgcrypt20-dev_1.9.4-3ubuntu3.3_amd64.deb ...
# Unpacking libgcrypt20-dev (1.9.4-3ubuntu3.3) ...
# Selecting previously unselected package libgmpxx4ldbl:amd64.
# Preparing to unpack .../19-libgmpxx4ldbl_2%3a6.2.1+dfsg-3ubuntu1_amd64.deb ...
# Unpacking libgmpxx4ldbl:amd64 (2:6.2.1+dfsg-3ubuntu1) ...
# Selecting previously unselected package libgmp-dev:amd64.
# Preparing to unpack .../20-libgmp-dev_2%3a6.2.1+dfsg-3ubuntu1_amd64.deb ...
# Unpacking libgmp-dev:amd64 (2:6.2.1+dfsg-3ubuntu1) ...
# Selecting previously unselected package libgnutls-openssl27:amd64.
# Preparing to unpack .../21-libgnutls-openssl27_3.7.3-4ubuntu1.9_amd64.deb ...
# Unpacking libgnutls-openssl27:amd64 (3.7.3-4ubuntu1.9) ...
# Selecting previously unselected package libunbound8:amd64.
# Preparing to unpack .../22-libunbound8_1.13.1-1ubuntu5.15_amd64.deb ...
# Unpacking libunbound8:amd64 (1.13.1-1ubuntu5.15) ...
# Selecting previously unselected package libgnutls-dane0:amd64.
# Preparing to unpack .../23-libgnutls-dane0_3.7.3-4ubuntu1.9_amd64.deb ...
# Unpacking libgnutls-dane0:amd64 (3.7.3-4ubuntu1.9) ...
# Selecting previously unselected package libgnutlsxx28:amd64.
# Preparing to unpack .../24-libgnutlsxx28_3.7.3-4ubuntu1.9_amd64.deb ...
# Unpacking libgnutlsxx28:amd64 (3.7.3-4ubuntu1.9) ...
# Selecting previously unselected package libidn2-dev:amd64.
# Preparing to unpack .../25-libidn2-dev_2.3.2-2build1_amd64.deb ...
# Unpacking libidn2-dev:amd64 (2.3.2-2build1) ...
# Selecting previously unselected package libp11-kit-dev:amd64.
# Preparing to unpack .../26-libp11-kit-dev_0.24.0-6ubuntu0.1_amd64.deb ...
# Unpacking libp11-kit-dev:amd64 (0.24.0-6ubuntu0.1) ...
# Selecting previously unselected package libtasn1-6-dev:amd64.
# Preparing to unpack .../27-libtasn1-6-dev_4.18.0-4ubuntu0.2_amd64.deb ...
# Unpacking libtasn1-6-dev:amd64 (4.18.0-4ubuntu0.2) ...
# Selecting previously unselected package nettle-dev:amd64.
# Preparing to unpack .../28-nettle-dev_3.7.3-1build2_amd64.deb ...
# Unpacking nettle-dev:amd64 (3.7.3-1build2) ...
# Selecting previously unselected package libgnutls28-dev:amd64.
# Preparing to unpack .../29-libgnutls28-dev_3.7.3-4ubuntu1.9_amd64.deb ...
# Unpacking libgnutls28-dev:amd64 (3.7.3-4ubuntu1.9) ...
# Selecting previously unselected package libgraphite2-dev:amd64.
# Preparing to unpack .../30-libgraphite2-dev_1.3.14-1ubuntu0.1_amd64.deb ...
# Unpacking libgraphite2-dev:amd64 (1.3.14-1ubuntu0.1) ...
# Selecting previously unselected package libharfbuzz-icu0:amd64.
# Preparing to unpack .../31-libharfbuzz-icu0_2.7.4-1ubuntu3.2_amd64.deb ...
# Unpacking libharfbuzz-icu0:amd64 (2.7.4-1ubuntu3.2) ...
# Selecting previously unselected package libharfbuzz-gobject0:amd64.
# Preparing to unpack .../32-libharfbuzz-gobject0_2.7.4-1ubuntu3.2_amd64.deb ...
# Unpacking libharfbuzz-gobject0:amd64 (2.7.4-1ubuntu3.2) ...
# Selecting previously unselected package libharfbuzz-dev:amd64.
# Preparing to unpack .../33-libharfbuzz-dev_2.7.4-1ubuntu3.2_amd64.deb ...
# Unpacking libharfbuzz-dev:amd64 (2.7.4-1ubuntu3.2) ...
# Selecting previously unselected package liblzo2-dev:amd64.
# Preparing to unpack .../34-liblzo2-dev_2.10-2build3_amd64.deb ...
# Unpacking liblzo2-dev:amd64 (2.10-2build3) ...
# Selecting previously unselected package libossp-uuid16:amd64.
# Preparing to unpack .../35-libossp-uuid16_1.6.2-1.5build9_amd64.deb ...
# Unpacking libossp-uuid16:amd64 (1.6.2-1.5build9) ...
# Selecting previously unselected package libossp-uuid-dev:amd64.
# Preparing to unpack .../36-libossp-uuid-dev_1.6.2-1.5build9_amd64.deb ...
# Unpacking libossp-uuid-dev:amd64 (1.6.2-1.5build9) ...
# Selecting previously unselected package libthai-dev:amd64.
# Preparing to unpack .../37-libthai-dev_0.1.29-1build1_amd64.deb ...
# Unpacking libthai-dev:amd64 (0.1.29-1build1) ...
# Selecting previously unselected package pango1.0-tools.
# Preparing to unpack .../38-pango1.0-tools_1.50.6+ds-2ubuntu1_amd64.deb ...
# Unpacking pango1.0-tools (1.50.6+ds-2ubuntu1) ...
# Selecting previously unselected package libpango1.0-dev:amd64.
# Preparing to unpack .../39-libpango1.0-dev_1.50.6+ds-2ubuntu1_amd64.deb ...
# Unpacking libpango1.0-dev:amd64 (1.50.6+ds-2ubuntu1) ...
# Selecting previously unselected package libpulse-mainloop-glib0:amd64.
# Preparing to unpack .../40-libpulse-mainloop-glib0_1%3a15.99.1+dfsg1-1ubuntu2.2_amd64.deb ...
# Unpacking libpulse-mainloop-glib0:amd64 (1:15.99.1+dfsg1-1ubuntu2.2) ...
# Selecting previously unselected package libpulse-dev:amd64.
# Preparing to unpack .../41-libpulse-dev_1%3a15.99.1+dfsg1-1ubuntu2.2_amd64.deb ...
# Unpacking libpulse-dev:amd64 (1:15.99.1+dfsg1-1ubuntu2.2) ...
# Selecting previously unselected package libsasl2-dev.
# Preparing to unpack .../42-libsasl2-dev_2.1.27+dfsg2-3ubuntu1.2_amd64.deb ...
# Unpacking libsasl2-dev (2.1.27+dfsg2-3ubuntu1.2) ...
# Selecting previously unselected package libswscale-dev:amd64.
# Preparing to unpack .../43-libswscale-dev_7%3a4.4.2-0ubuntu0.22.04.1_amd64.deb ...
# Unpacking libswscale-dev:amd64 (7:4.4.2-0ubuntu0.22.04.1) ...
# Selecting previously unselected package libtool.
# Preparing to unpack .../44-libtool_2.4.6-15build2_all.deb ...
# Unpacking libtool (2.4.6-15build2) ...
# Selecting previously unselected package libtool-bin.
# Preparing to unpack .../45-libtool-bin_2.4.6-15build2_amd64.deb ...
# Unpacking libtool-bin (2.4.6-15build2) ...
# Selecting previously unselected package libuv1-dev:amd64.
# Preparing to unpack .../46-libuv1-dev_1.43.0-1ubuntu0.1_amd64.deb ...
# Unpacking libuv1-dev:amd64 (1.43.0-1ubuntu0.1) ...
# Selecting previously unselected package libvncserver-dev:amd64.
# Preparing to unpack .../47-libvncserver-dev_0.9.13+dfsg-3ubuntu0.2_amd64.deb ...
# Unpacking libvncserver-dev:amd64 (0.9.13+dfsg-3ubuntu0.2) ...
# Selecting previously unselected package libev4:amd64.
# Preparing to unpack .../48-libev4_1%3a4.33-1_amd64.deb ...
# Unpacking libev4:amd64 (1:4.33-1) ...
# Selecting previously unselected package libwebsockets16:amd64.
# Preparing to unpack .../49-libwebsockets16_4.0.20-2ubuntu1.1_amd64.deb ...
# Unpacking libwebsockets16:amd64 (4.0.20-2ubuntu1.1) ...
# Selecting previously unselected package libev-dev:amd64.
# Preparing to unpack .../50-libev-dev_1%3a4.33-1_amd64.deb ...
# Unpacking libev-dev:amd64 (1:4.33-1) ...
# Selecting previously unselected package libwebsockets-dev:amd64.
# Preparing to unpack .../51-libwebsockets-dev_4.0.20-2ubuntu1.1_amd64.deb ...
# Unpacking libwebsockets-dev:amd64 (4.0.20-2ubuntu1.1) ...
# Setting up libavutil-dev:amd64 (7:4.4.2-0ubuntu0.22.04.1) ...
# Setting up libuv1-dev:amd64 (1.43.0-1ubuntu0.1) ...
# Setting up libharfbuzz-icu0:amd64 (2.7.4-1ubuntu3.2) ...
# Setting up libgnutls-openssl27:amd64 (3.7.3-4ubuntu1.9) ...
# Setting up libtool (2.4.6-15build2) ...
# Setting up libswresample-dev:amd64 (7:4.4.2-0ubuntu0.22.04.1) ...
# Setting up libavcodec-dev:amd64 (7:4.4.2-0ubuntu0.22.04.1) ...
# Setting up libev4:amd64 (1:4.33-1) ...
# Setting up libfribidi-dev:amd64 (1.0.8-2ubuntu3.1) ...
# Setting up pango1.0-tools (1.50.6+ds-2ubuntu1) ...
# Setting up libavformat-dev:amd64 (7:4.4.2-0ubuntu0.22.04.1) ...
# Setting up libharfbuzz-gobject0:amd64 (2.7.4-1ubuntu3.2) ...
# Setting up libossp-uuid16:amd64 (1.6.2-1.5build9) ...
# Setting up libwinpr2-2:amd64 (2.6.1+dfsg1-3ubuntu2.11) ...
# Setting up libgraphite2-dev:amd64 (1.3.14-1ubuntu0.1) ...
# Setting up libsasl2-dev (2.1.27+dfsg2-3ubuntu1.2) ...
# Setting up libunbound8:amd64 (1.13.1-1ubuntu5.15) ...
# Setting up libgmpxx4ldbl:amd64 (2:6.2.1+dfsg-3ubuntu1) ...
# Setting up libgpg-error-dev (1.43-3) ...
# Setting up libpulse-mainloop-glib0:amd64 (1:15.99.1+dfsg1-1ubuntu2.2) ...
# Setting up libswscale-dev:amd64 (7:4.4.2-0ubuntu0.22.04.1) ...
# Setting up libssl-dev:amd64 (3.0.2-0ubuntu1.29) ...
# Setting up libgnutlsxx28:amd64 (3.7.3-4ubuntu1.9) ...
# Setting up libidn2-dev:amd64 (2.3.2-2build1) ...
# Setting up libpulse-dev:amd64 (1:15.99.1+dfsg1-1ubuntu2.2) ...
# Setting up liblzo2-dev:amd64 (2.10-2build3) ...
# Setting up libdatrie-dev:amd64 (0.2.13-2) ...
# Setting up libossp-uuid-dev:amd64 (1.6.2-1.5build9) ...
# Setting up libev-dev:amd64 (1:4.33-1) ...
# Setting up libtasn1-6-dev:amd64 (4.18.0-4ubuntu0.2) ...
# Setting up libcap-dev:amd64 (1:2.44-1ubuntu0.22.04.3) ...
# Setting up libp11-kit-dev:amd64 (0.24.0-6ubuntu0.1) ...
# Setting up libtool-bin (2.4.6-15build2) ...
# Setting up libgnutls-dane0:amd64 (3.7.3-4ubuntu1.9) ...
# Setting up libharfbuzz-dev:amd64 (2.7.4-1ubuntu3.2) ...
# Setting up libgmp-dev:amd64 (2:6.2.1+dfsg-3ubuntu1) ...
# Setting up nettle-dev:amd64 (3.7.3-1build2) ...
# Setting up libwebsockets16:amd64 (4.0.20-2ubuntu1.1) ...
# Setting up libfreerdp2-2:amd64 (2.6.1+dfsg1-3ubuntu2.11) ...
# Setting up libwinpr-tools2-2:amd64 (2.6.1+dfsg1-3ubuntu2.11) ...
# Setting up libwinpr2-dev:amd64 (2.6.1+dfsg1-3ubuntu2.11) ...
# Setting up libgcrypt20-dev (1.9.4-3ubuntu3.3) ...
# Setting up winpr-utils (2.6.1+dfsg1-3ubuntu2.11) ...
# Setting up libthai-dev:amd64 (0.1.29-1build1) ...
# Setting up libfreerdp-server2-2:amd64 (2.6.1+dfsg1-3ubuntu2.11) ...
# Setting up libfreerdp-shadow2-2:amd64 (2.6.1+dfsg1-3ubuntu2.11) ...
# Setting up libfreerdp-client2-2:amd64 (2.6.1+dfsg1-3ubuntu2.11) ...
# Setting up libwebsockets-dev:amd64 (4.0.20-2ubuntu1.1) ...
# Setting up libgnutls28-dev:amd64 (3.7.3-4ubuntu1.9) ...
# Setting up libfreerdp-shadow-subsystem2-2:amd64 (2.6.1+dfsg1-3ubuntu2.11) ...
# Setting up libvncserver-dev:amd64 (0.9.13+dfsg-3ubuntu0.2) ...
# Setting up libpango1.0-dev:amd64 (1.50.6+ds-2ubuntu1) ...
# Setting up freerdp2-dev (2.6.1+dfsg1-3ubuntu2.11) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
#       ✅ Dependencias instaladas
#    ↳ [3/5] Compilando guacd (puede tardar 3-5 min)...
#    Init scripts: /etc/init.d
#    Systemd units: no
#
# Type "make" to compile guacamole-server.
#
#   CCLD     guaclog
# make[2]: Leaving directory '/tmp/guacamole-server-1.5.5/src/guaclog'
# make[2]: Entering directory '/tmp/guacamole-server-1.5.5'
# make[2]: Leaving directory '/tmp/guacamole-server-1.5.5'
# make[1]: Leaving directory '/tmp/guacamole-server-1.5.5'
# make[2]: Entering directory '/tmp/guacamole-server-1.5.5'
# make[2]: Nothing to be done for 'install-exec-am'.
# make[2]: Nothing to be done for 'install-data-am'.
# make[2]: Leaving directory '/tmp/guacamole-server-1.5.5'
# make[1]: Leaving directory '/tmp/guacamole-server-1.5.5'
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
#       ✅ guacd: /usr/local/sbin/guacd
#    ↳ [4/5] Instalando Tomcat...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libeclipse-jdt-core-java libtomcat9-java tomcat9-common
# Suggested packages:
#   tomcat9-admin tomcat9-docs tomcat9-examples tomcat9-user
# Recommended packages:
#   libtcnative-1
# The following NEW packages will be installed:
#   libeclipse-jdt-core-java libtomcat9-java tomcat9 tomcat9-common
# 0 upgraded, 4 newly installed, 0 to remove and 109 not upgraded.
# Need to get 12.4 MB of archives.
# After this operation, 15.3 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libeclipse-jdt-core-java all 3.27.0+eclipse4.21-1 [6,240 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libtomcat9-java all 9.0.58-1ubuntu0.2 [6,048 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 tomcat9-common all 9.0.58-1ubuntu0.2 [60.9 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 tomcat9 all 9.0.58-1ubuntu0.2 [37.0 kB]
# Fetched 12.4 MB in 2s (5,083 kB/s)
# Selecting previously unselected package libeclipse-jdt-core-java.
# (Reading database ... 128446 files and directories currently installed.)
# Preparing to unpack .../libeclipse-jdt-core-java_3.27.0+eclipse4.21-1_all.deb ...
# Unpacking libeclipse-jdt-core-java (3.27.0+eclipse4.21-1) ...
# Selecting previously unselected package libtomcat9-java.
# Preparing to unpack .../libtomcat9-java_9.0.58-1ubuntu0.2_all.deb ...
# Unpacking libtomcat9-java (9.0.58-1ubuntu0.2) ...
# Selecting previously unselected package tomcat9-common.
# Preparing to unpack .../tomcat9-common_9.0.58-1ubuntu0.2_all.deb ...
# Unpacking tomcat9-common (9.0.58-1ubuntu0.2) ...
# Selecting previously unselected package tomcat9.
# Preparing to unpack .../tomcat9_9.0.58-1ubuntu0.2_all.deb ...
# Unpacking tomcat9 (9.0.58-1ubuntu0.2) ...
# Setting up libeclipse-jdt-core-java (3.27.0+eclipse4.21-1) ...
# Setting up libtomcat9-java (9.0.58-1ubuntu0.2) ...
# Setting up tomcat9-common (9.0.58-1ubuntu0.2) ...
# Setting up tomcat9 (9.0.58-1ubuntu0.2) ...
# Creating group tomcat with gid 999.
# Creating user tomcat (Apache Tomcat) with uid 999 and gid 999.
#
# Creating config file /etc/tomcat9/tomcat-users.xml with new version
#
# Creating config file /etc/tomcat9/web.xml with new version
#
# Creating config file /etc/tomcat9/server.xml with new version
#
# Creating config file /etc/tomcat9/logging.properties with new version
#
# Creating config file /etc/tomcat9/context.xml with new version
#
# Creating config file /etc/tomcat9/catalina.properties with new version
#
# Creating config file /etc/tomcat9/jaspic-providers.xml with new version
#
# Creating config file /etc/logrotate.d/tomcat9 with new version
#
# Creating config file /etc/default/tomcat9 with new version
# Created symlink /etc/systemd/system/multi-user.target.wants/tomcat9.service → /lib/systemd/system/tomcat9.service.
#       ✅ Tomcat instalado
#    ↳ [5/5] Desplegando Guacamole web app...
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   ✅ Apache Guacamole instalado
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# ✅ Instalacion completada

# %%
#@title 🚀 Iniciar Escritorio
# %cd /content/Maquina-v7/scripts
# !bash start_desktop.sh {RESOLUTION} {USERNAME} {PASSWORD} {GUAC_PORT}

# Detectar URL publica de cloudflared
import re
public_url = ""
try:
    with open("/tmp/cloudflared.log") as f:
        for line in f:
            m = re.search(r'https://[a-zA-Z0-9._-]+\.trycloudflare\.com', line)
            if m:
                public_url = m.group(0)
                break
except FileNotFoundError:
    pass

print("\n" + "="*50)
print("  🌐 COMO ACCEDER:")
print("="*50)
if public_url:
    print(f"  ✅ URL PUBLICA (desde cualquier dispositivo):")
    print(f"     {public_url}")
    print(f"")
print(f"  URL local (solo Colab): http://localhost:{GUAC_PORT}")
print(f"")
print(f"  Usuario : {USERNAME}")
print(f"  Password: {PASSWORD}")
print("="*50)
# Out:
# /content/Maquina-v7/scripts
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   🚀 MAQUINA-V7 — Iniciando escritorio
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#   🖥️  Desktop      : LXQt
#   🌐 Gateway      : Apache Guacamole
#   🔗 Backend      : VNC (x11vnc)
#   📺 Resolucion   : 1920x1080
#
#   🎮 Detectando GPU...
#   🎮 GPU          : NVIDIA Tesla T4
#
#    ↳ Deteniendo procesos previos...
#    ↳ [1/6] Iniciando Xvfb (display :10)...
#       ✅ Xvfb listo
#    ↳ [2/6] Iniciando PulseAudio...
#       ✅ PulseAudio listo
#       🔊 Audio Monitor: auto_null.monitor
#    ↳ [3/6] Iniciando LXQt...
# "Icon Theme not set. Fallbacking to Oxygen, if installed"
# "Fallback Icon Theme (Oxygen) not found"
# lxqt-session: LockScreenManager couldn't start
#       ✅ LXQt listo (PID: 22019)
#    ↳ [4/6] Iniciando x11vnc...
#       ✅ x11vnc listo (PID: 22039)
#    ↳ [5/6] Iniciando guacd...
#       ✅ guacd listo (PID: 22042)
#    ↳ [6/6] Iniciando Apache Guacamole...
#       Esperando Guacamole...
#       ✅ Guacamole listo
#    ↳ [7/7] Creando tunnel publico...
#       ✅ Tunnel listo
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   ✅ Escritorio iniciado correctamente
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#   🌐 URL PUBLICA (abre desde cualquier dispositivo):
#      https://explains-semester-pattern-behalf.trycloudflare.com
#
#   🌐 GUACAMOLE (local):
#      http://localhost:8080
#
#   📊 Estado:
#      ✅ Xvfb: ejecutandose
#      ✅ PulseAudio: ejecutandose
#      ✅ LXQt: ejecutandose
#      ✅ x11vnc: ejecutandose
#      ✅ guacd: ejecutandose
#      ✅ Guacamole: ejecutandose
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━

# %%
#@title 📊 Estado del Sistema
# %cd /content/Maquina-v7/scripts
# !bash diagnostics.sh

# %%
#@title 🔒 Keep-Alive (anti-apagado de Colab)
import threading, time

def _heartbeat():
    while True:
        time.sleep(60)
        print("♥ keep-alive", time.strftime('%H:%M:%S'))
threading.Thread(target=_heartbeat, daemon=True).start()
print('✅ Keep-alive activado.')
print('⚠️ NO cierres ni ocultes esta pestaña de Colab.')

# %%
#@title 🎮 Instalar Steam (opcional)
INSTALL_STEAM = True  #@param {type:"boolean"}
if INSTALL_STEAM:
    # %cd /content/Maquina-v7/scripts
    # !bash install_steam.sh
else:
    print('Omitido (INSTALL_STEAM = False).')

# %%
# Crear túnel público con Cloudflare (rápido)
# !npx --yes cloudflared tunnel --url http://localhost:8080
